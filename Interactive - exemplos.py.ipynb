# %% [markdown]
# Connected to Python 3.12.1

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv')

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=5)

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=5)

classInit.raw_data
# Out:
#                      DeslocamentoemBreak (Standard)  27,58437   mm
# 0  Deslocamento \xe0 tra\xe7\xe3oemBreak (Standard)  22.92945   mm
# 1                                  Observa\xe7\xe3o       NaN  NaN

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=10)

classInit.raw_data
# Out:
#          (s)      (mm)        (N)    (mm).1
# 0      0.000   0.00600    3.46858   0.32635
# 1      0.010   0.00650    3.45768   0.32660
# 2      0.020   0.00850    3.50164   0.32681
# 3      0.030   0.01275    3.73627   0.32689
# 4      0.040   0.01950    4.40845   0.32668
# ...      ...       ...        ...       ...
# 1978  19.764  28.08431  402.86963  23.52330
# 1979  19.774  28.16762  396.18314  23.62658
# 1980  19.784  28.25093  381.98331  23.73096
# 1981  19.794  28.33431  302.90915  23.86651
# 1982  19.798  28.36769  259.31808  23.95987
#
# [1983 rows x 4 columns]

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)

classInit.raw_data
# Out:
#          Tempo  Travessa      Carga Extensometro
# 0          (s)      (mm)        (N)         (mm)
# 1      0,00000   0,00600    3,46858      0,32635
# 2      0,01000   0,00650    3,45768      0,32660
# 3      0,02000   0,00850    3,50164      0,32681
# 4      0,03000   0,01275    3,73627      0,32689
# ...        ...       ...        ...          ...
# 1979  19,76400  28,08431  402,86963     23,52330
# 1980  19,77400  28,16762  396,18314     23,62658
# 1981  19,78400  28,25093  381,98331     23,73096
# 1982  19,79400  28,33431  302,90915     23,86651
# 1983  19,79800  28,36769  259,31808     23,95987
#
# [1984 rows x 4 columns]

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=10)

classInit.raw_data
# Out:
#          (s)      (mm)        (N)    (mm).1
# 0      0.000   0.00600    3.46858   0.32635
# 1      0.010   0.00650    3.45768   0.32660
# 2      0.020   0.00850    3.50164   0.32681
# 3      0.030   0.01275    3.73627   0.32689
# 4      0.040   0.01950    4.40845   0.32668
# ...      ...       ...        ...       ...
# 1978  19.764  28.08431  402.86963  23.52330
# 1979  19.774  28.16762  396.18314  23.62658
# 1980  19.784  28.25093  381.98331  23.73096
# 1981  19.794  28.33431  302.90915  23.86651
# 1982  19.798  28.36769  259.31808  23.95987
#
# [1983 rows x 4 columns]

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)

classInit.raw_data
# Out:
#          Tempo  Travessa      Carga Extensometro
# 0          (s)      (mm)        (N)         (mm)
# 1      0,00000   0,00600    3,46858      0,32635
# 2      0,01000   0,00650    3,45768      0,32660
# 3      0,02000   0,00850    3,50164      0,32681
# 4      0,03000   0,01275    3,73627      0,32689
# ...        ...       ...        ...          ...
# 1979  19,76400  28,08431  402,86963     23,52330
# 1980  19,77400  28,16762  396,18314     23,62658
# 1981  19,78400  28,25093  381,98331     23,73096
# 1982  19,79400  28,33431  302,90915     23,86651
# 1983  19,79800  28,36769  259,31808     23,95987
#
# [1984 rows x 4 columns]

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)

classInit.raw_data.drop(axis=1, index=0)
# Out:
#          Tempo  Travessa      Carga Extensometro
# 1      0,00000   0,00600    3,46858      0,32635
# 2      0,01000   0,00650    3,45768      0,32660
# 3      0,02000   0,00850    3,50164      0,32681
# 4      0,03000   0,01275    3,73627      0,32689
# 5      0,04000   0,01950    4,40845      0,32668
# ...        ...       ...        ...          ...
# 1979  19,76400  28,08431  402,86963     23,52330
# 1980  19,77400  28,16762  396,18314     23,62658
# 1981  19,78400  28,25093  381,98331     23,73096
# 1982  19,79400  28,33431  302,90915     23,86651
# 1983  19,79800  28,36769  259,31808     23,95987
#
# [1983 rows x 4 columns]

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)
# limpando tirando a primeira linha
classInit.raw_data.drop(axis=1, index=0)
# Out:
#          Tempo  Travessa      Carga Extensometro
# 1      0,00000   0,00600    3,46858      0,32635
# 2      0,01000   0,00650    3,45768      0,32660
# 3      0,02000   0,00850    3,50164      0,32681
# 4      0,03000   0,01275    3,73627      0,32689
# 5      0,04000   0,01950    4,40845      0,32668
# ...        ...       ...        ...          ...
# 1979  19,76400  28,08431  402,86963     23,52330
# 1980  19,77400  28,16762  396,18314     23,62658
# 1981  19,78400  28,25093  381,98331     23,73096
# 1982  19,79400  28,33431  302,90915     23,86651
# 1983  19,79800  28,36769  259,31808     23,95987
#
# [1983 rows x 4 columns]

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData, plot_helper
import matplotlib.pyplot as plt
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)
# limpando tirando a primeira linha
classInit.raw_data.drop(axis=1, index=0)

fig, ax = plt.subplots(figsize=(4,4))

plot_helper(ax=ax,x=classInit.raw_data['Extensometro'], y=classInit.raw_data['Carga'], label='Polimero', xlabel='Deslocamento', ylabel='Carga [N]')
# Out:
# <Axes: xlabel='Deslocamento', ylabel='Carga [N]'>

# %%
classInit.raw_data['Extensometro']
# Out:
# 0           (mm)
# 1        0,32635
# 2        0,32660
# 3        0,32681
# 4        0,32689
#           ...
# 1979    23,52330
# 1980    23,62658
# 1981    23,73096
# 1982    23,86651
# 1983    23,95987
# Name: Extensometro, Length: 1984, dtype: object

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData, plot_helper
import matplotlib.pyplot as plt
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)
# limpando tirando a primeira linha
df  = classInit.raw_data.drop(axis=1, index=0)

fig, ax = plt.subplots(figsize=(4,4))

plot_helper(ax=ax,x=df['Extensometro'], y=df['Carga'], label='Polimero', xlabel='Deslocamento', ylabel='Carga [N]')
# Out:
# <Axes: xlabel='Deslocamento', ylabel='Carga [N]'>

# %%
df['Extensometro']
# Out:
# 1        0,32635
# 2        0,32660
# 3        0,32681
# 4        0,32689
# 5        0,32668
#           ...
# 1979    23,52330
# 1980    23,62658
# 1981    23,73096
# 1982    23,86651
# 1983    23,95987
# Name: Extensometro, Length: 1983, dtype: object

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData, plot_helper
import matplotlib.pyplot as plt
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)
# limpando tirando a primeira linha
df  = classInit.raw_data.drop(axis=1, index=0)
df.describe()
fig, ax = plt.subplots(figsize=(4,4))

plot_helper(ax=ax,x=df['Extensometro'], y=df['Carga'], label='Polimero', xlabel='Deslocamento', ylabel='Carga [N]')
# Out:
# <Axes: xlabel='Deslocamento', ylabel='Carga [N]'>

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData, plot_helper
import matplotlib.pyplot as plt
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)
# limpando tirando a primeira linha
df  = classInit.raw_data.drop(axis=1, index=0)
df.describe()
# fig, ax = plt.subplots(figsize=(4,4))

# plot_helper(ax=ax,x=df['Extensometro'], y=df['Carga'], label='Polimero', xlabel='Deslocamento', ylabel='Carga [N]')
# Out:
#           Tempo Travessa      Carga Extensometro
# count      1983     1983       1983         1983
# unique     1983     1983       1982         1978
# top     0,00000  0,00600  725,05353      0,32635
# freq          1        1          2            2

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData, plot_helper
import matplotlib.pyplot as plt
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)
# limpando tirando a primeira linha
df  = classInit.raw_data.drop(axis=1, index=0)
df.info()
# fig, ax = plt.subplots(figsize=(4,4))

# plot_helper(ax=ax,x=df['Extensometro'], y=df['Carga'], label='Polimero', xlabel='Deslocamento', ylabel='Carga [N]')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1983 entries, 1 to 1983
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tempo         1983 non-null   object
#  1   Travessa      1983 non-null   object
#  2   Carga         1983 non-null   object
#  3   Extensometro  1983 non-null   object
# dtypes: object(4)
# memory usage: 62.1+ KB

# %%
'''
Gerando 10 corpos de prova fakes a partir de um corpo base
'''
import pandas as pd
from experimentalTreatingIsiPol.main import ReadExperimentalData, plot_helper
import matplotlib.pyplot as plt
classInit = ReadExperimentalData(archive_name=r'D:\Jonas\Mini Curso Python\experimental_data\exemplo_polimero.csv', skiprows=9)
# limpando tirando a primeira linha
df  = classInit.raw_data.drop(axis=1, index=0)
df['Extensometro'] = df['Extensometro'].astype(float)
# fig, ax = plt.subplots(figsize=(4,4))

# plot_helper(ax=ax,x=df['Extensometro'], y=df['Carga'], label='Polimero', xlabel='Deslocamento', ylabel='Carga [N]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Jonas\Mini Curso Python\exemplos.py:11
#       9 # limpando tirando a primeira linha
#      10 df  = classInit.raw_data.drop(axis=1, index=0)
# ---> 11 df['Extensometro'] = df['Extensometro'].astype(float)
#      12 # fig, ax = plt.subplots(figsize=(4,4))
#      13
#      14 # plot_helper(ax=ax,x=df['Extensometro'], y=df['Carga'], label='Polimero', xlabel='Deslocamento', ylabel='Carga [N]')
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
 df['Extensometro']
# Out:
# 1        0,32635
# 2        0,32660
# 3        0,32681
# 4        0,32689
# 5        0,32668
#           ...
# 1979    23,52330
# 1980    23,62658
# 1981    23,73096
# 1982    23,86651
# 1983    23,95987
# Name: Extensometro, Length: 1983, dtype: object
